# %%
print ("Hello World")
# Out:
# Hello World

# %%
patient_name = "Nirvana"
age = 21
weight = 55
have_diabetes = "False"

print(patient_name)
print(age)
print(weight)
print(have_diabetes)
# Out:
# Nirvana
# 21
# 55
# False

# %%
tablet_count = 30

print(tablet_count)
# Out:
# 30

# %%
patient_name = "Nirvana"
age = 21
medication = "Paracetamol"
dose = 50
instruction = "Take with Food"

print("======= PRESCRIPTION =======")
print("Patient:",patient_name)
print("Age:",age)
print("Medication:",medication)
print("Dose:",dose)
print("Instruction:",instruction)
print("============================")
# Out:
# ======= PRESCRIPTION =======
# Patient: Nirvana
# Age: 21
# Medication: Paracetamol
# Dose: 50
# Instruction: Take with Food
# ...
