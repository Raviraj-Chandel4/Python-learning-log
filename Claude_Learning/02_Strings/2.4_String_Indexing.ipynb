# %%
medicine = "Aspirin"
print(medicine[0])
print(medicine[1])
print(medicine[-1])
print(medicine[-2])
# Out:
# A
# s
# n
# i

# %% [markdown]
# A string is like a pill organiser - each compartment (character) has a number, starting from 0.

# %%
medicine = "Aspirin"
print(medicine[0:3])
print(medicine[2:5])
print(medicine[ :4])
print(medicine[4: ])
# Out:
# Asp
# pir
# Aspi
# rin

# %% [markdown]
# Slicing: Grabbing a chunk
