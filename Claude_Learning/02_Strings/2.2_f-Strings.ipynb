# %%
name = "Sara"
dose = "500"
print(f"Patient:{name},Dose:{dose}mg")
# Out:
# Patient:Sara,Dose:500mg

# %%
medicine = "Amoxicillin"
frequency = 3
duration = 7

print(f"Medication:{medicine}")
print(f"Take {frequency} times per day for {duration} days")
print(f"Total tablets needed: {frequency*duration}")
# Out:
# Medication:Amoxicillin
# Take 3 times per day for 7 days
# Total tablets needed: 21
