# %%
first_name = "Sara"
last_name = "Khan"
full_name = first_name + " " + last_name

print(full_name)
# Out:
# Sara Khan

# %% [markdown]
# Joining Strings - Concatenation

# %%
letter = "R" * 20
print(letter)
# Out:
# RRRRRRRRRRRRRRRRRRRR

# %% [markdown]
# Repeating Strings

# %%
medicines = "Acetylsalicylic acid"
print(len(medicines))
# Out:
# 20

# %% [markdown]
# Measuring length

# %%
name = "Nirvana"
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# NIRVANA
# nirvana
# Nirvana

# %% [markdown]
# UPPER, lower, Title

# %%
messy = "     Paracetamol     "
clean = messy.strip()
print(clean)
# Out:
# Paracetamol

# %% [markdown]
# Removing Extra Spaces

# %%
prescription = "Take with Food and Water"
print("Food" in prescription)
print("Alcohol" in prescription)
# Out:
# True
# False

# %% [markdown]
# Checking what's inside

# %%
instruction = "Take 1 tablet daily"
updated = instruction.replace("daily", "twice daily")
print(updated)
# Out:
# Take 1 tablet twice daily

# %% [markdown]
# Replacing Text
