# %%
name = input("What is your name?")
print(f"Hell0, {name}! Welcome to the pharmacy system.")
# Out:
# What is your name?Nirvana
# Hell0, Nirvana! Welcome to the pharmacy system.

# %% [markdown]
# When you run this, Python will pause and wait for you to type somethings, then continue.

# %%
age = input ("Enter your age:")
print(type(age))
# Out:
# Enter your age:21
# <class 'str'>

# %% [markdown]
# #<class 'str'> <----- it's a string, not a number!

# %%
age = int(input("Enter your age:"))
Weight = float(input("Enter your weight:"))
# Out:
# Enter your age:21
# Enter your weight:55

# %% [markdown]
# This is called the TYPE CASTING - changing one data type to another.

# %%
print("===== PATIENT INTAKE FORM =====")
name = input("Patient Name:")
age = int(input("Age:"))
weight = float(input("Weight (kg):"))
allergy = input("Any known alleries?")

print("\n===== SUMMARY =====")
print(f"Name    : {name}")
print(f"Age     : {age} years")
print(f"Weight  : {weight}Kg")
print(f"Allergy : {allergy}")
print(f"BMI note: Patient weight {weight} Kg at age {age}")
# Out:
# ===== PATIENT INTAKE FORM =====
# Patient Name:Nirvana
# Age:21
# Weight (kg):55
# Any known alleries?no
#
# ===== SUMMARY =====
# Name    : Nirvana
# Age     : 21 years
# Weight  : 55.0Kg
# Allergy : no
# BMI note: Patient weight 55.0 Kg at age 21

# %% [markdown]
# The \n inside a string means "new line" - it adds a blanks line for readability.
